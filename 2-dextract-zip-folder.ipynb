# %%
# import zipfile
# import os

# # ==== CONFIG ====
# zip_path = "okutama-action/Sample.zip"        # 🔹 Path to your zip file
# extract_to = "okutama-action/Sample"   # 🔹 Folder where you want to extract

# # ==== UNZIP PROCESS ====
# os.makedirs(extract_to, exist_ok=True)

# with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#     zip_ref.extractall(extract_to)

# print(f"✅ Extracted successfully to: {extract_to}")
# Out:
# ✅ Extracted successfully to: okutama-action/Sample

# %%
# import zipfile
# import os

# # ==== CONFIG ====
# zip_path = "okutama-action/TestSetVideos.zip"        # 🔹 Path to your zip file
# extract_to = "okutama-action/TestSetVideos"   # 🔹 Folder where you want to extract

# # ==== UNZIP PROCESS ====
# os.makedirs(extract_to, exist_ok=True)

# with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#     zip_ref.extractall(extract_to)

# print(f"✅ Extracted successfully to: {extract_to}")
# Out:
# ✅ Extracted successfully to: okutama-action/TestSetVideos
